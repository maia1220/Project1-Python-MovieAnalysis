# %%
import pandas as pd

# %%
# Load the dataset
movie_df = pd.read_csv('tmdb-movie-metadata/tmdb_5000_movies.csv')

# Preview the dataset
movie_df.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
# Check data types
movie_df.dtypes

'''
All numeric variables in insterest are either interger or float. 
'''
# Out:
# '\nAll numeric variables in insterest are either interger or float. \n'

# %%
# Check observation counts for each variable
print(movie_df.count())
# Out:
# budget                  4803
# genres                  4803
# homepage                1712
# id                      4803
# keywords                4803
# original_language       4803
# original_title          4803
# overview                4800
# popularity              4803
# production_companies    4803
# production_countries    4803
# release_date            4802
# revenue                 4803
# runtime                 4801
# spoken_languages        4803
# status                  4803
# tagline                 3959
# title                   4803
# vote_average            4803
# vote_count              4803
# dtype: int64

# %%
# Missing data cleaning
'''
"homepage", "overview", "tagline" will be dropped since we don't include these varaibles 
in analysis.
'''
# Make a new dataset as a copy
clean1_df=movie_df.copy()

# Delete the unused columns
clean1_df.drop(['homepage', 'overview', 'tagline'], axis=1, inplace=True)

# Drop missing data
clean2_df = clean1_df.dropna()


clean2_df.count()
# final number of observation came down to 4800.
# Out:
# budget                  4800
# genres                  4800
# id                      4800
# keywords                4800
# original_language       4800
# original_title          4800
# popularity              4800
# production_companies    4800
# production_countries    4800
# release_date            4800
# revenue                 4800
# runtime                 4800
# spoken_languages        4800
# status                  4800
# title                   4800
# vote_average            4800
# vote_count              4800
# dtype: int64

# %%
# Check the summary statistics
clean2_df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.800000e+03    4800.000000  4800.000000  4.800000e+03  4800.000000
# mean   2.906007e+07   56949.011667    21.505569  8.231205e+07   106.898125
# std    4.073029e+07   88292.839372    31.822163  1.628950e+08    22.561593
# min    0.000000e+00       5.000000     0.000372  0.000000e+00     0.000000
# 25%    8.000000e+05    9012.750000     4.682212  0.000000e+00    94.000000
# 50%    1.500000e+07   14623.500000    12.928897  1.918199e+07   103.000000
# 75%    4.000000e+07   58512.500000    28.350628  9.293886e+07   118.000000
# max    3.800000e+08  447027.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4800.000000   4800.000000
# mean       6.094458    690.646875
# std        1.188366   1234.852449
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    236.000000
# 75%        6.800000    737.250000
# ...

# %%
# Check missing values

zero_budget=pd.DataFrame(clean2_df.loc[clean2_df["budget"]==0])                      
valid_budget=pd.DataFrame(clean2_df.loc[clean2_df["budget"] > 0])


print(zero_budget.count()) 
# 1036 observation has a budget of $0. 

print(valid_budget["budget"].value_counts())

# multiple imputation: replace the zero values to the mean value
mean_budget= (clean2_df["budget"].mean())
clean2_df["budget"]=clean2_df["budget"].replace({0: mean_budget})

print(f'The average budget is {mean_budget}')
# Out:
# budget                  1036
# genres                  1036
# id                      1036
# keywords                1036
# original_language       1036
# original_title          1036
# popularity              1036
# production_companies    1036
# production_countries    1036
# release_date            1036
# revenue                 1036
# runtime                 1036
# spoken_languages        1036
# status                  1036
# title                   1036
# vote_average            1036
# vote_count              1036
# dtype: int64
# 20000000    144
# 30000000    128
# 25000000    126
# 40000000    123
# 15000000    119
#            ...
# 3180000       1
# 5952000       1
# 3730500       1
# 78146652      1
# 40600000      1
# Name: budget, Length: 434, dtype: int64
# The average budget is 29060068.024791665
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Check missing values

zero_revenue=pd.DataFrame(clean2_df.loc[clean2_df["revenue"]==0])                      
valid_revenue=pd.DataFrame(clean2_df.loc[clean2_df["revenue"] > 0])

zero_revenue.count()

# multiple imputation: replace the zero values to the mean value
mean_revenue= (clean2_df["revenue"].mean())
clean2_df["revenue"]=clean2_df["revenue"].replace({0: mean_revenue})

print(f'The average revenue is {mean_revenue}')
# Out:
# The average revenue is 82312051.55083333
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Check missing values

zero_runtime=pd.DataFrame(clean2_df.loc[clean2_df["runtime"]==0])                      
valid_runtime=pd.DataFrame(clean2_df.loc[clean2_df["runtime"] > 0])

zero_runtime.count()

# multiple imputation: replace the zero values to the mean value
mean_runtime= (clean2_df["runtime"].mean())
clean2_df["runtime"]=clean2_df["runtime"].replace({0: mean_runtime})

print(f'The average runtime is {mean_runtime}')
# Out:
# The average runtime is 106.898125
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Check missing values

zero_vote_average=pd.DataFrame(clean2_df.loc[clean2_df["vote_average"]==0])                      
valid_vote_average=pd.DataFrame(clean2_df.loc[clean2_df["vote_average"] > 0])

zero_vote_average.count()

# multiple imputation: replace the zero values to the mean value
mean_vote_average= (clean2_df["vote_average"].mean())
clean2_df["vote_average"]=clean2_df["vote_average"].replace({0: mean_vote_average})

print(f'The average vote average is {mean_vote_average}')
# Out:
# The average vote average is 6.094458333333329
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Check missing values

zero_vote_count=pd.DataFrame(clean2_df.loc[clean2_df["vote_count"]==0])                      
valid_vote_count=pd.DataFrame(clean2_df.loc[clean2_df["vote_count"] > 0])

zero_vote_count.count()

# multiple imputation: replace the zero values to the mean value
mean_vote_count= (clean2_df["vote_count"].mean())
clean2_df["vote_count"]=clean2_df["vote_count"].replace({0: mean_vote_count})

print(f'The average vote count is {mean_vote_count}')
# Out:
# The average vote count is 690.646875
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
# Check the summary statistics of the final dataset

clean2_df.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.800000e+03    4800.000000  4800.000000  4.800000e+03  4800.000000
# mean   3.533220e+07   56949.011667    21.505569  1.067313e+08   107.655320
# std    3.791177e+07   88292.839372    31.822163  1.546866e+08    20.675889
# min    1.000000e+00       5.000000     0.000372  5.000000e+00    14.000000
# 25%    1.200000e+07    9012.750000     4.682212  2.758125e+07    94.000000
# 50%    2.906007e+07   14623.500000    12.928897  8.231205e+07   104.000000
# 75%    4.000000e+07   58512.500000    28.350628  9.293886e+07   118.000000
# max    3.800000e+08  447027.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4800.000000   4800.000000
# mean       6.171909    699.279961
# std        0.966487   1232.405116
# min        0.500000      1.000000
# 25%        5.600000     59.000000
# 50%        6.200000    250.000000
# 75%        6.800000    737.250000
# ...

# %%
# Check unique identifier
clean2_df["id"].is_unique
# Out:
# True

# %%
# Set index (run only once)

clean2_df.set_index("id", inplace=True)

# %%
# sort index

clean2_df.sort_index(axis=0, inplace=True)
clean2_df.head()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         budget                                             genres  \
# id
# 5    4000000.0  [{"id": 80, "name": "Crime"}, {"id": 35, "name...
# 11  11000000.0  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12  94000000.0  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 13  55000000.0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 14  15000000.0                      [{"id": 18, "name": "Drama"}]
#
#                                              keywords original_language  \
# id
# 5   [{"id": 612, "name": "hotel"}, {"id": 613, "na...                en
# ...
